# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("md.csv", index_col=0)
df[["Potential Energy (kJ/mole)","Kinetic Energy (kJ/mole)", "Total Energy (kJ/mole)"]].plot()
# Out:
# <AxesSubplot: xlabel='#"Time (ps)"'>

# %%
df.tail()
# Out:
#               Potential Energy (kJ/mole)  Kinetic Energy (kJ/mole)  \
# #"Time (ps)"
# 3.84                       -145408.75103              22814.323636
# 3.88                       -145248.00103              22565.495348
# 3.92                       -145355.03228              22787.295268
# 3.96                       -145686.87603              23210.156511
# 4.00                       -145244.25103              22780.919562
#
#               Total Energy (kJ/mole)  Temperature (K)  Box Volume (nm^3)  \
# #"Time (ps)"
# 3.84                  -122594.427394       291.969827          98.828311
# 3.88                  -122682.505683       288.785408          98.828311
# 3.92                  -122567.737012       291.623927          98.828311
# 3.96                  -122476.719519       297.035559          98.828311
# 4.00                  -122463.331468       291.542333          98.828311
#
#               Density (g/mL)  Speed (ns/day)
# #"Time (ps)"
# ...
